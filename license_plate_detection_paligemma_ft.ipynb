# %% [markdown]
# ## Setup and Imports

# %%
! pip install -U -q transformers
! pip install -U -q accelerate
! pip install -U -q datasets

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from transformers import (
    AutoProcessor,
    PaliGemmaForConditionalGeneration
)
from datasets import load_dataset

import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# ## Configuration

# %%
dataset_id = "ariG23498/license-detection-paligemma"
model_id = "google/paligemma-3b-pt-224"

device = "cuda:0"
dtype = torch.bfloat16

batch_size = 8
learning_rate = 5e-5

# %% [markdown]
# ## Dataset for Fine Tuning

# %%
train_dataset = load_dataset(dataset_id, split="train")
val_dataset = load_dataset(dataset_id, split="validation")
test_dataset = load_dataset(dataset_id, split="test")

# %%
print(f"{len(train_dataset)=}")
print(f"{len(val_dataset)=}")
print(f"{len(test_dataset)=}")
# Out:
# len(train_dataset)=4323
# len(val_dataset)=1482
# len(test_dataset)=371

# %%
processor = AutoProcessor.from_pretrained(model_id)

# %%
def collate_train_fn(examples):
    images = [example["image"].convert("RGB") for example in examples]

    prompt = ["Detect license plate." for _ in examples]
    suffix = [example["label_for_paligemma"] for example in examples]

    # Help from: https://github.com/huggingface/transformers/issues/30987
    inputs = processor(
        images=images,
        text=prompt,
        suffix=suffix,
        return_tensors="pt",
        padding="longest",
    )

    inputs = inputs.to(torch.bfloat16).to(device)
    return inputs

def collate_test_fn(examples):
    images = [example["image"].convert("RGB") for example in examples]

    prompt = ["Detect license plate." for _ in examples]

    inputs = processor(
        images=images,
        text=prompt,
        return_tensors="pt",
        padding="longest",
    )

    inputs = inputs.to(torch.bfloat16).to(device)
    return inputs

# %%
train_dataloader = DataLoader(
    train_dataset,
    collate_fn=collate_train_fn,
    batch_size=batch_size,
    shuffle=True,
)

val_dataloader = DataLoader(
    val_dataset,
    collate_fn=collate_train_fn,
    batch_size=batch_size,
    shuffle=False,
)

test_dataloader = DataLoader(
    test_dataset,
    collate_fn=collate_test_fn,
    batch_size=batch_size,
    shuffle=False,
)

# %% [markdown]
# ## Model creation

# %%
model = PaliGemmaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=dtype,
    device_map=device,
    revision="bfloat16",
)
# Out:
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Freezing everything but the attention layers

# %%
for name, param in model.named_parameters():
    if "attn" in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
for name, param in model.named_parameters():
    print(f"{name:<70}: requires_grad={param.requires_grad}, dtype={param.dtype}")
# Out:
# vision_tower.vision_model.embeddings.patch_embedding.weight           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.embeddings.patch_embedding.bias             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.embeddings.position_embedding.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.0.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.1.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.2.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.3.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.4.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.5.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.6.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.7.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.8.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.weight    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.bias      : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.weight  : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.bias    : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.layer_norm1.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.layer_norm1.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.mlp.fc1.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.mlp.fc1.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.mlp.fc2.weight             : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.mlp.fc2.bias               : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.layer_norm2.weight         : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.9.layer_norm2.bias           : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.10.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.11.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.12.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.13.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.14.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.15.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.16.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.17.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.18.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.19.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.20.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.21.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.22.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.23.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.24.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.v_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.q_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.q_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.out_proj.weight : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.self_attn.out_proj.bias   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.layer_norm1.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.layer_norm1.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.mlp.fc1.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.mlp.fc1.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.mlp.fc2.weight            : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.mlp.fc2.bias              : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.layer_norm2.weight        : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.25.layer_norm2.bias          : requires_grad=False, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.26.self_attn.k_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.26.self_attn.k_proj.bias     : requires_grad=True, dtype=torch.bfloat16
# vision_tower.vision_model.encoder.layers.26.self_attn.v_proj.weight   : requires_grad=True, dtype=torch.bfloat16
# ...
# language_model.model.layers.2.mlp.up_proj.weight                      : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers
proj.weight                   : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.16.mlp.up_proj.weight                     : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.16.mlp.down_proj.weight                   : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.16.input_layernorm.weight                 : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.16.post_attention_layernorm.weight        : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.17.self_attn.q_proj.weight                : requires_grad=True, dtype=torch.bfloat16
# language_model.model.layers.17.self_attn.k_proj.weight                : requires_grad=True, dtype=torch.bfloat16
# language_model.model.layers.17.self_attn.v_proj.weight                : requires_grad=True, dtype=torch.bfloat16
# language_model.model.layers.17.self_attn.o_proj.weight                : requires_grad=True, dtype=torch.bfloat16
# language_model.model.layers.17.mlp.gate_proj.weight                   : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.17.mlp.up_proj.weight                     : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.17.mlp.down_proj.weight                   : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.17.input_layernorm.weight                 : requires_grad=False, dtype=torch.bfloat16
# language_model.model.layers.17.post_attention_layernorm.weight        : requires_grad=False, dtype=torch.bfloat16
# language_model.model.norm.weight                                      : requires_grad=False, dtype=torch.bfloat16

# %% [markdown]
# ## Dummy forward pass

# %%
val_batch = next(iter(val_dataloader))
test_batch = next(iter(test_dataloader))

# %%
print(f"{val_batch.keys()=}")
print(f"{test_batch.keys()=}")
# Out:
# val_batch.keys()=dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'pixel_values', 'labels'])
# test_batch.keys()=dict_keys(['input_ids', 'attention_mask', 'pixel_values'])

# %%
outputs = model(**val_batch)
print(f"{outputs.loss=}")
# Out:
# outputs.loss=tensor(5.6800, device='cuda:0', grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## Results Before Fine Tuning

# %%
with torch.inference_mode():
    generation = model.generate(**test_batch, max_new_tokens=100, do_sample=False)
    decoded = processor.batch_decode(generation, skip_special_tokens=True)

# %%
for element in decoded:
    location = element.split("\n")[1]
    if location == "":
        print("No bbox found")
    else:
        print(location)
# Out:
# No bbox found
# No bbox found
# No bbox found
# No bbox found
# No bbox found
# No bbox found
# No bbox found
# No bbox found

# %% [markdown]
# ## Fine tune the model

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(1):
    for idx, batch in enumerate(train_dataloader):
        outputs = model(**batch)
        loss = outputs.loss
        if idx % 500 == 0:
            print(f"Epoch: {epoch} Iter: {idx} Loss: {loss.item():.4f}")

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
# Out:
# Epoch: 0 Iter: 0 Loss: 5.6340
# Epoch: 0 Iter: 500 Loss: 2.2826

# %% [markdown]
# ## Results After Fine Tuning

# %%
DETECT_RE = re.compile(
    r'(.*?)' +
    r'((?:<loc\d{4}>){4})\s*' +
    r'([^;<>]+) ?(?:; )?',
)

# %%
def extract_objects(detection_string, image_width, image_height, unique_labels=False):
    objects = []
    seen_labels = set()

    while detection_string:
        match = DETECT_RE.match(detection_string)
        if not match:
            break

        prefix, locations, label = match.groups()
        location_values = [int(loc) for loc in re.findall(r'\d{4}', locations)]
        y1, x1, y2, x2 = [value / 1024 for value in location_values]
        y1, x1, y2, x2 = map(round, (y1 * image_height, x1 * image_width, y2 * image_height, x2 * image_width))

        label = label.strip()  # Remove trailing spaces from label

        if unique_labels and label in seen_labels:
            label = (label or '') + "'"
        seen_labels.add(label)

        objects.append(dict(
            xyxy=(x1, y1, x2, y2),
            name=label
        ))

        detection_string = detection_string[len(match.group()):]

    return objects

# %%
def draw_bbox(image, objects):
    fig, ax = plt.subplots(1)
    ax.imshow(image)
    for obj in objects:
        bbox = obj["xyxy"]
        rect = patches.Rectangle(
            (bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1],
            linewidth=2, edgecolor='r', facecolor='none'
        )
        ax.add_patch(rect)
        plt.text(bbox[0], bbox[1] - 10, "plate", color='red', fontsize=12, weight='bold')
    plt.show()

# %%
with torch.inference_mode():
    generation = model.generate(**test_batch, max_new_tokens=100, do_sample=False)
    decoded = processor.batch_decode(generation, skip_special_tokens=True)

# %%
for index in range(batch_size):
    image = test_batch["pixel_values"][index].permute(1, 2, 0).cpu().float()
    element = decoded[index]
    detection_string = element.split("\n")[1]
    objects = extract_objects(detection_string, 224, 224, unique_labels=False)
    draw_bbox(image, objects)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
